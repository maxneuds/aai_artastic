# %% [markdown]
# ## get artwork df

# %%
import pandas as pd
import json
import requests
import wget
import time
import os
from SPARQLWrapper import SPARQLWrapper, JSON

def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)
  
q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX : <http://h-da.de/fbi/artontology/>

SELECT ?artwork ?url ?name ?abstract (group_concat(?motif;separator=';') as ?motifs)
WHERE {
  # ?artwork rdf:type :artwork;
     rdfs:label ?name;
     :image ?url;
     :abstract ?abstract;
     :motif/rdfs:label ?motif.
}
group by ?artwork ?url ?name ?abstract
"""

ds = "http://neuds.de:3030/artontology"
df = get_sparql_dataframe(ds, q)
df['id'] = df['artwork'].map(lambda x: x.split('/')[-1])
df.head()
# Out:
#                                     artwork  \
# 0  http://www.wikidata.org/entity/Q29019486
# 1   http://www.wikidata.org/entity/Q7527543
# 2   http://www.wikidata.org/entity/Q3944494
# 3    http://www.wikidata.org/entity/Q368788
# 4   http://www.wikidata.org/entity/Q3630743
#
#                                                  url  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                 name  \
# 0  Saint Proculus of Pozzuoli and his mother Sant...
# 1                        Statue of John A. Macdonald
# 2  The Holy Family with Saint Catherine of Alexan...
# 3                                              Pietà
# 4                     Self-Portrait at the Age of 63
#
#                                             abstract  \
# 0  Saints Proculus and Nicea is a 1636-1637 paint...
# 1  The Sir John A. Macdonald statue is a bronze s...
# 2  Holy Family with Saint Catherine of Alexandria...
# 3  Pietà is a painting by the Italian Renaissance...
# 4  Self-Portrait at the Age of 63 is a self-portr...
#
#                                               motifs         id
# 0        Nicea;Saint Procolo;Saint Procolo and Nicea  Q29019486
# 1                                  John A. Macdonald   Q7527543
# 2  Virgin Mary;Catherine of Alexandria;boy;Child ...   Q3944494
# 3                 Virgin Mary;Jesus Christ;man;woman    Q368788
# 4                                      Rembrandt;man   Q3630743

# %% [markdown]
# ## create model

# %% [markdown]
# prepare corpus

# %%
from collections import defaultdict
from gensim.utils import simple_preprocess
from gensim import corpora
from gensim import models
from gensim import similarities

text_corpus = df['abstract'].values

# Create a set of frequent words
stoplist = set('for a of the and to in'.split(' '))
# Lowercase each document, split it by white space and filter out stopwords
texts = [[word for word in document.lower().split() if word not in stoplist]
         for document in text_corpus]

# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# Only keep words that appear more than once
processed_corpus = [[token for token in text if frequency[token] > 3] for text in texts]
# create dictionary
art_dict = corpora.Dictionary(processed_corpus)
# create bow
bow_corpus = [art_dict.doc2bow(text) for text in processed_corpus]
# create tfidf model
tfidf = models.TfidfModel(bow_corpus)

# %% [markdown]
# ## tests

# %%
words = df[df['id'] == 'Q3630743']['abstract'].values[0].lower().split()
print(tfidf[art_dict.doc2bow(words)])
# Out:
# [(4, 0.03914012914889163), (6, 0.06393841288682726), (7, 0.007054869085089224), (18, 0.0009280072527049965), (19, 0.030456457869645865), (26, 0.01117035765207907), (34, 0.07990437425779509), (35, 0.0820346801897768), (37, 0.0491973845526996), (46, 0.03234060587361309), (49, 0.08261169672403249), (65, 0.10313427813835543), (76, 0.012723314984494945), (77, 0.02900833133146859), (86, 0.11481248072126692), (90, 0.06294919270537178), (109, 0.05961919481930718), (113, 0.020161725454353), (115, 0.02682094643053469), (121, 0.06655619075700493), (132, 0.05078901017176469), (135, 0.021181315547168605), (138, 0.05553040989065565), (146, 0.11670848601006444), (147, 0.1096038114387776), (148, 0.09475721812502487), (149, 0.09952211777936648), (150, 0.11400741409730408), (151, 0.12381316058135125), (152, 0.05634978280958678), (153, 0.1199031760153161), (154, 0.10608760262390701), (155, 0.05399836130963105), (156, 0.09561213321333133), (157, 0.07757084989432693), (158, 0.08140278407075766), (159, 0.09170214864729614), (160, 0.05517819132802337), (161, 0.028336161329523175), (162, 0.04351881742316346), (163, 0.0879329060708147), (164, 0.11400741409730408), (165, 0.17311732160438464), (166, 0.10456296460907204), (167, 0.1199031760153161), (168, 0.09561213321333133), (169, 0.10065298004303688), (170, 0.029994912266020742), (171, 0.10775765461432371), (172, 0.058957898093226796), (173, 0.08027192180708727), (174, 0.08303394085431744), (175, 0.06364186326882995), (176, 0.05312405243573193), (177, 0.05236539353092791), (178, 0.0863143145681765), (179, 0.03395156073045851), (180, 0.07991062481127215), (181, 0.06906364430753921), (182, 0.04798655735496164), (183, 0.08971637129531931), (184, 0.06496215746931067), (185, 0.09316318483733059), (186, 0.05950723096554966), (187, 0.0984598359691689), (188, 0.039852515205478195), (189, 0.07442838730030257), (190, 0.058957898093226796), (191, 0.036044616641442734), (192, 0.20276163203804573), (193, 0.059373911192012546), (194, 0.06364186326882995), (195, 0.16017918681485108), (196, 0.05720935869948853), (197, 0.09101491219257878), (198, 0.078208094065506), (199, 0.08850745864204448), (200, 0.07067602553774162), (201, 0.05579929931287539), (202, 0.10608760262390701), (203, 0.10065298004303688), (204, 0.1018618926963117), (205, 0.11901446193109932), (206, 0.06202327176619172), (207, 0.07110341949421918), (208, 0.0863143145681765), (209, 0.05007208452159998), (210, 0.08391023762129193), (211, 0.10573233638170304), (212, 0.10608760262390701), (213, 0.07199081333787506), (214, 0.04993921253053342), (215, 0.09775240886763134), (216, 0.057111741268772886), (217, 0.10608760262390701), (218, 0.09101491219257878), (219, 0.12381316058135125), (220, 0.09952211777936648), (221, 0.11748579610466534), (222, 0.0698512952691206), (223, 0.07391298886505139), (224, 0.22821691837890412), (225, 0.07991062481127215), (226, 0.08910149124139981), (227, 0.08910149124139981), (228, 0.09241744320807965), (229, 0.12381316058135125), (230, 0.127853569450618), (231, 0.11400741409730408), (232, 0.05720935869948853), (233, 0.05327980709234215), (234, 0.1199031760153161), (235, 0.08261169672403249), (236, 0.054832913486297485), (237, 0.023437196113025888), (238, 0.06511519148567099), (239, 0.04703004760936177), (240, 0.11400741409730408), (241, 0.033668314124247804), (242, 0.08219938867765099), (243, 0.04234878669852118), (244, 0.07416879316718411), (245, 0.22333527836071773), (246, 0.037193039237460646), (247, 0.05917556901035415), (248, 0.11166763918035887), (249, 0.057605359361264215), (250, 0.10775765461432371), (251, 0.12700224255855241)]

# %% [markdown]
# ## ideas

# %% [markdown]
# simple doc

# %%
from gensim.matutils import cossim as csim
s1 = df[df['id'] == 'Q179900']['abstract'].values[0].lower().split()
s2 = df[df['id'] == 'Q205259']['abstract'].values[0].lower().split()
v1 = art_dict.doc2bow(s1)
v2 = art_dict.doc2bow(s2)
size_art = len(art_dict)
print(csim(v1, v2))
# Out:
# 0.17818653576961846

# %% [markdown]
# lda

# %%
import pickle
lda_model = pickle.load(open('nlp_lda.pkl', 'rb'))
lda_dict = pickle.load(open('nlp_dict.pkl', 'rb'))

s1 = df[df['id'] == 'Q179900']['abstract'].values[0].lower().split()
s2 = df[df['id'] == 'Q205259']['abstract'].values[0].lower().split()
v1 = lda_dict.doc2bow(s1)
v2 = lda_dict.doc2bow(s2)
lda1 = lda[v1]
lda2 = lda[v2]
print(csim(lda1, lda2))
# Out:
# 0.776296337124219
